# %% [markdown]
# # Perkata

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/Aku.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "aku"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan aku"
            else:
                gesture = "aku"
            
        
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Masukkan kata: Aku Aku

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/Dia.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "Dia"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan dia"
            else:
                gesture = "dia"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/Kamu.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "kamu"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan kamu"
            else:
                gesture = "kamu"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/Nama.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi kedua tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=2) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "nama"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y and \
               thumb_tip.x < index_finger_tip.x and \
               index_finger_tip.x < middle_finger_tip.x and \
               middle_finger_tip.x < ring_finger_tip.x and \
               ring_finger_tip.x < pinky_tip.x:
                gesture = "Bukan Nama"
            else:
                gesture = "Nama"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/saya.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi kedua tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=2) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "saya"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y and \
               thumb_tip.x < index_finger_tip.x and \
               index_finger_tip.x < middle_finger_tip.x and \
               middle_finger_tip.x < ring_finger_tip.x and \
               ring_finger_tip.x < pinky_tip.x:
                gesture = "Bukan saya"
            else:
                gesture = "saya"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# # Huruf

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils


# Membaca gambar
image = cv2.imread('D://SIBI/huruf A.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "aku"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan A"
            else:
                gesture = "A"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf B.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "aku"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan B"
            else:
                gesture = "B"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf C.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "C"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan C"
            else:
                gesture = "C"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf D.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "D"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan D"
            else:
                gesture = "D"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf F.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "F"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan F"
            else:
                gesture = "F"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf G.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "G"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan G"
            else:
                gesture = "G"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf H.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "H"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan H"
            else:
                gesture = "H"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf I.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "aku"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan I"
            else:
                gesture = "I"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils



# Membaca gambar
image = cv2.imread('D://SIBI/huruf J.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "aku"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan J"
            else:
                gesture = "J"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/hurufK.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "k"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan K"
            else:
                gesture = "K"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils


# Membaca gambar
image = cv2.imread('D://SIBI/huruf L.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "L"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan L"
            else:
                gesture = "L"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf M.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "aku"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan M"
            else:
                gesture = "M"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils


# Membaca gambar
image = cv2.imread('D://SIBI/huruf N.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "N"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan N"
            else:
                gesture = "N"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf O.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "O"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan O"
            else:
                gesture = "O"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf P.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "p"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan p"
            else:
                gesture = "p"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf Q.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "Q"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan Q"
            else:
                gesture = "Q"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf R.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "R"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan R"
            else:
                gesture = "R"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf T.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "T"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan T"
            else:
                gesture = "T"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf S.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "S"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan S"
            else:
                gesture = "S"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf W.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "W"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan W"
            else:
                gesture = "W"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Membaca gambar
image = cv2.imread('D://SIBI/huruf X.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "aku"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan X"
            else:
                gesture = "X"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Menginisialisasi MediaPipe
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils


# Membaca gambar
image = cv2.imread('D://SIBI/huruf Y.jpg')  # Ganti dengan path file gambar yang ingin Anda impor

# Mengubah ukuran gambar menjadi lebih kecil
width = 640  # Ganti dengan lebar yang diinginkan
height = int(image.shape[0] * width / image.shape[1])
resized_image = cv2.resize(image, (width, height))

# Mengubah gambar menjadi grayscale
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

# Mendeteksi tangan
with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
    # Mendapatkan hasil deteksi tangan
    results = hands.process(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    
    # Menggambar landmark tangan
    annotated_image = resized_image.copy()
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            
            # Mengartikan gerakan tangan sebagai "Y"
            thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
            index_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            middle_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
            ring_finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP]
            pinky_tip = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]
            
            if thumb_tip.y < index_finger_tip.y and \
               index_finger_tip.y < middle_finger_tip.y and \
               middle_finger_tip.y < ring_finger_tip.y and \
               ring_finger_tip.y < pinky_tip.y:
                gesture = "bukan Y"
            else:
                gesture = "Y"
            
            # Menampilkan arti gerakan tangan
            cv2.putText(annotated_image, gesture, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
    # Menampilkan gambar dengan landmark tangan dan arti gerakan tangan
    cv2.imshow('Hand Detection', annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
